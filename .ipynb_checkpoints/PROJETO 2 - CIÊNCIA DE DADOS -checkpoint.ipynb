# %% [markdown]
# # Projeto 2 - Ciência de Dados
#
# **Integrantes:**
# - Pedro de Souza (Turma 2A)
# - Tomás Fiorelli Barbosa (Turma 2B)
#
# **Informações da base de dados:**
# A base de dados utilizada nos informa sobre os maiores bilionários do mundo, determinado pela Forbes, renomada revista de negócios e economia. Os arquivos foram extraidos do site Kaggle e, por possuir mais de uma versão (a base de dados), porém com as informações atualizadas em todos, foi de interesse extrair a coluna *Industry* da segunda versão e adicioná-la à primeira (na leitura dos dataframes isso será apresentado).

# %%
# Bibliotecas Importadas

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leitura dos DataFrames

dados_1 = pd.read_csv("forbes_billionaires_geo.csv")
dados_2 = pd.read_csv("Billionaire.csv")

colunas_de_interesse = ['Name','NetWorth','Country',
                        'Source','Rank','Age',
                        'Residence','Citizenship','Status',
                        'Children','Education','Self_made']

bilionarios = dados_1.loc[:, colunas_de_interesse]
bilionarios['Industry'] = dados_2['Industry']

# %% [markdown]
# ### Variáveis da base de dados
# - **Name**: nome do bilionário
# - **NetWorth**: fortuna, em bilhões de dólares
# - **Country**: país sede da empresa
# - **Source**: fonte da fortuna
# - **Rank**: ranking da Forbes
# - **Age**: idade
# - **Residence**: local da residência
# - **Citizenship**: cidadania
# - **Status**: estado civil
# - **Children**: número de filhos
# - **Education**: curso e universidade
# - **Self_made**: self made ou não
# - **Industry**: indústria de atuação

# %%
bilionarios
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
# Transformação das Variáveis Categóricas

bilionarios['Country'] = bilionarios['Country'].astype('category')         # country

bilionarios['Source'] = bilionarios['Source'].astype('category')           # source

bilionarios['Residence'] = bilionarios['Residence'].astype('category')     # residence

bilionarios['Citizenship'] = bilionarios['Citizenship'].astype('category') # citizenship

bilionarios['Status'] = bilionarios['Status'].astype('category')           # status

bilionarios['Education'] = bilionarios['Education'].astype('category')     # education

bilionarios['Industry'] = bilionarios['Industry'].astype('category')       # industry

# Verificação
bilionarios['Citizenship'].cat.categories
# Out:
# Index(['Algeria', 'Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil',
#        'Canada', 'Chile', 'China', 'Colombia', 'Cyprus', 'Czechia', 'Denmark',
#        'Egypt', 'Eswatini (Swaziland)', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Guernsey', 'Hong Kong', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Kazakhstan', 'Lebanon', 'Liechtenstein', 'Macao', 'Malaysia', 'Mexico',
#        'Monaco', 'Morocco', 'Nepal', 'Netherlands', 'New Zealand', 'Nigeria',
#        'Norway', 'Oman', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar',
#        'Romania', 'Russia', 'Singapore', 'Slovakia', 'South Africa',
#        'South Korea', 'Spain', 'St. Kitts and Nevis', 'Sweden', 'Switzerland',
#        'Taiwan', 'Tanzania', 'Thailand', 'Turkey', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Venezuela',
#        'Vietnam', 'Zimbabwe'],
#       dtype='object')

# %%
# lista_curso = []
# lista_college = []
# lista_doiscu= []
# lista_doisco = []




# for v in bilionarios['Education']:
#     if v != '0':
#         if ';' in list(str(v)):
#             y = v.split(';')
#             z = y[0].split(',')
#             p = y[1].split(',')
#             lista_doiscu.append(z[0])
#             lista_doiscu.append(z[1])
#             lista_doisco.append(p[0])
#             lista_doisco.append(p[1])
            
#             lista_curso.append(lista_doiscu)
#             lista_college.append(lista_doisco)
            
#         else:
#             y = v.split(',')
#             lista_curso.append(y[0])
#             lista_college.append(y[1])
    
#     elif v == '0':
#         lista_curso.append('No info')
#         lista_college.append('No info')

# %%
# lista_curso = []
# lista_college = []

# for v in bilionarios['Education']:
#     if ';' in list(v):
#         lista_sup_curso = []
#         lista_sup_college = []
#         p = v.split(';')
#         for i in p:
#             i.split(',')
#             lista_sup_curso.append(i[0])
#             lista_sup_college.append(i[1])
#         lista_curso.append(lista_sup_curso)
#         lista_college.append(lista_sup_college)
#     else:
#         if v == 'No info':
#             lista_curso.append('No info')
#             lista_college.append('No info')
#         else:
#             p = v.split(',')
#             lista_curso.append(p[0])
#             lista_college.append(p[1])

# %% [markdown]
# ## Análise Exploratória

# %% [markdown]
# ### NetWorth

# %%
bilionarios.NetWorth.describe()
# Out:
# count    2755.000000
# mean        4.749220
# std         9.615358
# min         1.000000
# 25%         1.500000
# 50%         2.300000
# 75%         4.200000
# max       177.000000
# Name: NetWorth, dtype: float64

# %%
faixa = np.arange(1,180,1)
fig = plt.figure(figsize=(20,20))
bilionarios.NetWorth.plot.hist(bins=faixa, color =('green'),density=1,title = "NetWorth", alpha = 0.6)
plt.ylabel('Densidade')
plt.xlabel('Fortuna em bilhões')
plt.show()

# %%
y = bilionarios.NetWorth.value_counts()
x = bilionarios.NetWorth.value_counts().index.values
#x.sort()
#x
y
# Out:
# 1.1     150
# 1.2     146
# 1.4     122
# 1.3     115
# 1.5     106
#        ...
# 16.7      1
# 48.4      1
# 23.6      1
# 17.5      1
# 21.7      1
# Name: NetWorth, Length: 245, dtype: int64

# %%
plt.figure(figsize=(35,4))

plt.bar(y,x)
plt.show()

# %%
plt.figure(figsize=(10,15))
plt.title('Scatter Plot [NetWorth x Country]')
plt.scatter(bilionarios['NetWorth'], bilionarios['Country'], alpha=0.5, color='red')
plt.show()

# %% [markdown]
# ### Age

# %%
# Medidas Resumo

bilionarios['Age'].describe()
# Out:
# count    2630.00000
# mean       63.26730
# std        13.47916
# min        18.00000
# 25%        54.00000
# 50%        63.00000
# 75%        73.00000
# max        99.00000
# Name: Age, dtype: float64

# %% [markdown]
# ### Country

# %%
# Porcentagem

bilionarios['Country'].value_counts(normalize=True, dropna=False)
# Out:
# United States           0.262795
# China                   0.227223
# India                   0.050817
# Germany                 0.049365
# Russia                  0.042831
#                           ...
# Macao                   0.000363
# Liechtenstein           0.000363
# Guernsey                0.000363
# Eswatini (Swaziland)    0.000363
# Zimbabwe                0.000363
# Name: Country, Length: 70, dtype: float64

# %%
# Densidade

plt.figure(figsize=(10,15))
plt.title('Gráfico de Barras - Country')
plt.xlabel('Densidade')
plt.ylabel('Country')
bilionarios['Country'].value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### Citizenship

# %%
# Porcentagem

bilionarios['Citizenship'].value_counts(normalize=True, dropna=False)
# Out:
# United States           0.260617
# China                   0.225771
# India                   0.050091
# Germany                 0.049365
# Russia                  0.042831
#                           ...
# Eswatini (Swaziland)    0.000363
# Tanzania                0.000363
# Oman                    0.000363
# St. Kitts and Nevis     0.000363
# Algeria                 0.000363
# Name: Citizenship, Length: 71, dtype: float64

# %%
# Densidade

plt.figure(figsize=(10,15))
plt.title('Gráfico de Barras - Citizenship')
plt.xlabel('Densidade')
plt.ylabel('Citizenship')
bilionarios['Citizenship'].value_counts(normalize=True, dropna=False).plot.barh()
plt.show()

# %% [markdown]
# ### Status

# %%
# Porcentagem

bilionarios['Status'].value_counts(normalize=True, dropna=False)
# Out:
# Married               0.629401
# NaN                   0.241379
# Divorced              0.052269
# Widowed               0.034483
# Single                0.026860
# In Relationship       0.007623
# Separated             0.003630
# Widowed, Remarried    0.002904
# Engaged               0.001452
# Name: Status, dtype: float64

# %%
# Densidade

plt.figure(figsize=(10,5))
plt.title('Gráfico de Barras - Status')
plt.xlabel('Densidade')
plt.ylabel('Status')
bilionarios['Status'].value_counts(normalize=True, dropna=False).plot.barh()
plt.show()

# %%
# Boxplot 'Status x Age'

plt.figure(figsize=(15,5))
plt.title('Boxplot [Status x Age]')
sns.boxplot(bilionarios['Status'], bilionarios['Age'])
plt.show()
# Out:
# C:\Users\tomas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Children

# %%
bilionarios['Children'].describe()
# Out:
# count    1552.000000
# mean        2.978093
# std         1.618569
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        23.000000
# Name: Children, dtype: float64

# %% [markdown]
# ### Self_made

# %%
# Porcentagem

bilionarios['Self_made'].value_counts(normalize=True)
# Out:
# True     0.716113
# False    0.283887
# Name: Self_made, dtype: float64

# %%
# Gráfico de Pizza

plt.title('Gráfico de Pizza - Self_made')
bilionarios['Self_made'].value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# ### Industry

# %%
# Porcentagem

bilionarios['Industry'].value_counts(normalize=True)
# Out:
# Finance & Investments         0.134664
# Technology                    0.132486
# Manufacturing                 0.120145
# Fashion & Retail              0.099093
# Healthcare                    0.080218
# Food & Beverage               0.079492
# Real Estate                   0.078040
# Diversified                   0.068240
# Energy                        0.036298
# Media & Entertainment         0.034483
# Service                       0.027223
# Metals & Mining               0.026860
# Automotive                    0.024682
# Construction & Engineering    0.015971
# Logistics                     0.012704
# Telecom                       0.011615
# Gambling & Casinos            0.009074
# Sports                        0.008711
# Name: Industry, dtype: float64

# %%
# Densidade

plt.figure(figsize=(10,5))
plt.title('Gráfico de Barras - Industry')
plt.xlabel('Densidade')
plt.ylabel('Industry')
bilionarios['Industry'].value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### Correlação

# %%
bilionarios[['NetWorth', 'Age', 'Children']].corr()
# Out:
#           NetWorth       Age  Children
# NetWorth  1.000000  0.032572  0.053064
# Age       0.032572  1.000000  0.190316
# Children  0.053064  0.190316  1.000000
